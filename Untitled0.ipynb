# %% [markdown]
# <a href="https://colab.research.google.com/github/nataShep/C_sharp/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
# !pip install numpy

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("sample_data/spotify-2023_fixed.csv")
df.head(50)
df.loc[(df["released_year"] == 2023)]
# Out:
#                               track_name  \
# 0    Seven (feat. Latto) (Explicit Ver.)
# 1                                   LALA
# 2                                vampire
# 4                         WHERE SHE GOES
# 5                               Sprinter
# ..                                   ...
# 381         I'm Not Here To Make Friends
# 382                            TRUSTFALL
# 385            VIBE (feat. Jimin of BTS)
# 398                                 Mu��
# 404                      Sugar Rush Ride
#
#                              artist(s)_name  artist_count  released_year  \
# 0                          Latto, Jung Kook             2           2023
# 1                               Myke Towers             1           2023
# 2                            Olivia Rodrigo             1           2023
# 4                                 Bad Bunny             1           2023
# 5                         Dave, Central Cee             2           2023
# ...

# %%
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 6))
sns.set_theme(style="whitegrid")
sns.scatterplot(data=df, x='released_year', y='in_apple_playlists',
                hue='mode', size='artist_count',
                palette='crest')
plt.title("Spotify-2023")
plt.legend(title='Mode & artist_count')
plt.show()

# %% [markdown]
# Выборка по году релиза и количеству в плейлистах в Эппл.
# Дополнительные критерии: количество артистов, участвующих в написании сингла, и лады гармонической тональности.
# Сделала только один график, остальные варианты мне не понравились.

# %% [markdown]
# Алексей, благодарю вас за семинары. Сожалею, что не могла участвовать онлайн.
